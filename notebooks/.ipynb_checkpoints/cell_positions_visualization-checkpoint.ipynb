# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
os.getcwd()
# Out:
# '/srv/mfs/hausserlab/fabio/data_analysis/notebooks'

# %%
import pandas as pd
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from src.utils.visualization import plot_cells_positions
from src.CellsImage import CellsImage

# %%
patientID = 1
cell_data = pd.read_csv("../../output/cell_positions_data/patient{}_cell_positions.csv".format(patientID))
plot_cells_positions(cell_data, to_plot = 'all')
# Out:
# ['Kreatin-positive tumor' 'CD3-T' 'B' 'CD4-T' 'DC/Mono' 'Undefined'
#  'Macrophages' 'CD8-T' 'Other Immune' 'Endothelial' 'Mono/Neu'
#  'Mesenchymal-like' 'Neutrophils' 'NK' 'Tumor' 'DC']
# 16
# (3,)
# [ 87  31 252]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-88ea529ce669> in <module>
#       1 patientID = 1
#       2 cell_data = pd.read_csv("../../output/cell_positions_data/patient{}_cell_positions.csv".format(patientID))
# ----> 3 plot_cells_positions(cell_data, to_plot = 'all')
#
# /srv/mfs/hausserlab/fabio/data_analysis/src/utils/visualization.py in plot_cells_positions(data, to_plot)
#      32     #plt.scatter(xx, yy, marker='^', s=20)
#      33     z = get_segmentation_matrix()
# ---> 34     plt.imshow(z, origin='lower')
#      35
#      36     for (name, group), col in zip(groups, colors):
#
# ...

# %%
x = np.arange(0, 800, 10)
y = np.arange(0, 800, 10)
xx, yy = np.meshgrid(x, y)
xx, yy
# Out:
# (array([[  0,  10,  20, ..., 770, 780, 790],
#         [  0,  10,  20, ..., 770, 780, 790],
#         [  0,  10,  20, ..., 770, 780, 790],
#         ...,
#         [  0,  10,  20, ..., 770, 780, 790],
#         [  0,  10,  20, ..., 770, 780, 790],
#         [  0,  10,  20, ..., 770, 780, 790]]),
#  array([[  0,   0,   0, ...,   0,   0,   0],
#         [ 10,  10,  10, ...,  10,  10,  10],
#         [ 20,  20,  20, ...,  20,  20,  20],
#         ...,
#         [770, 770, 770, ..., 770, 770, 770],
#         [780, 780, 780, ..., 780, 780, 780],
#         [790, 790, 790, ..., 790, 790, 790]]))

# %%
DATA_PATH = "../../david_data"
data = pd.read_csv("{}/cellData.csv".format(DATA_PATH))

CELL_TYPES = ['Kreatin-positive tumor', 'Treg', 'CD3-T', 'Neutrophils', 'Tumor', 'B', 
              'Macrophages', 'Mesenchymal-like', 'Other Immune', 'CD8-T', 'CD4-T', 
              'Undefined', 'Mono/Neu', 'DC/Mono', 'Endothelial', 'DC', 'NK']

cell2id = {ct: i for i, ct in enumerate(CELL_TYPES)}

patients_idx = data['SampleID'].unique()
to_remove = np.array([42, 43, 44])
patients_idx = np.setdiff1d(patients_idx, to_remove)
 
def group_map(id, tumor_yn):
    labels = {0: [
        'Tumor', 'Treg', 'CD4-T', 'CD8-T', 'CD3-T', 'NK', 'B', 'Neutrophils',
        'Macrophages', 'DC', 'DC/Mono', 'Mono/Neu', 'Other Immune'],
        1: ['Undefined', 'Immune', 'Endothelial', 'Mesenchymal-like',
                  'Tumor', 'Kreatin-positive tumor']}
    id = id-1 if tumor_yn == 1 else id
    return labels[tumor_yn][id]

# %%
patientID = 10
patient_data = data[data['SampleID'] == patientID]
image = CellsImage(patientID)
print("Getting cells from image for patient: {}".format(patientID))
group = patient_data['Group']
immune_group = patient_data['immuneGroup']
tumorYN = patient_data['tumorYN']
cell_type = [group_map(g, t) if t == 1 else group_map(ig, t)
             for g, ig, t in zip(group, immune_group, tumorYN)]
img = image.get_colored_matrix(list(patient_data['cellLabelInImage']), cell_type, cell2id)
# Out:
# Getting cells from image for patient: 10

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img, cmap=cmap)
plt.show()
