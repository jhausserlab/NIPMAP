# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
os.getcwd()
# Out:
# '/scratch/anissa.el/MacroMicroNichesElMarrahi2022/data_analysis/notebooks/nature_cancer_building_blocks_analysis'

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from src.CellAbundance import CellAbundance, join_abundance_matrices, generate_abundance_matrix
from src.utils.archetypes import ArchetypalAnalysis
from src.utils.visualization import plot_scatter_pca, plot_3Dscatter_pca, archetypes_bar_plot, archetype_simple_plot
from src.utils.equations import arch2color, alfa2rgb, scale, color_mapper

# %% [markdown]
# ## 4 archetype analysis

# %%
ROOT_DATA_PATH = "../../data/tnbc_nature_cancer_dataset"
CELL_TYPES = ['Fibroblasts', 'Endothelial', 'T cells', 'B cells', 'Cancer', 'Vascular SMA+', 'Myoepithelial', 'Macrophages']
patient_ids = [ 88, 428, 357, 389, 303, 445, 374,  33, 549, 537, 477, 393, 429, 329, 443, 305, 105, 469, 555, 
               532,   6,  40, 415,   7, 221, 10, 395, 494, 332, 409,  87, 479, 359,  36, 265, 273, 229, 261, 
               184, 181, 521, 102, 468, 509,  92,  94, 331, 260, 250, 233, 234,236, 231, 170, 365, 175, 154,  19, 
               132,  98,  58,  61,  16,  63,432, 361, 263, 426, 366,  35, 340,   1, 336]

# %%
len(patient_ids)
# Out:
# 73

# %%
N_SITE = 100
RADIUS = 25

abs_log_ca_list = generate_abundance_matrix(CELL_TYPES, patient_ids, N_SITE, RADIUS, method='gaussian', snr=3, root=ROOT_DATA_PATH)
sites, patients_ids,sites_ids,_ = join_abundance_matrices(abs_log_ca_list)
pca = PCA()
pc = pca.fit_transform(sites)

# %%
#SLOW
n_archs = list(range(2, 6))

lst_exp_var = []
for n_arch in n_archs:
    AA = ArchetypalAnalysis(n_archetypes = n_arch, 
                        tolerance = 0.001, 
                        max_iter = 200, 
                        random_state = 0, 
                        C = 0.0001, 
                        initialize = 'random',
                        redundancy_try = 30)
    AA.fit(pc[:, :3])
    lst_exp_var.append(AA.explained_variance_)

plt.plot(n_archs, lst_exp_var, '-o')
plt.ylim(0, 1)
plt.show()
# Out:
# Warning: A redundant archetype was recognised. The redundancy issue was resolved after 1 try(s) and a new candidate is replaced.

# %%
n_components = 3
AA_3D = ArchetypalAnalysis(n_archetypes = 4, 
                        tolerance = 0.001, 
                        max_iter = 200, 
                        random_state = 0,
                        C = 0.0001, 
                        initialize = 'random',
                        redundancy_try = 30)

# %%
AA_3D.fit_transform(pc[:, :n_components])
# Out:
# array([[-1.62127289e+00, -5.80360856e-01, -5.85684132e-02],
#        [-1.62127289e+00, -5.80360856e-01, -5.85684132e-02],
#        [-8.02308055e-01, -7.31231090e-03, -1.29709636e-03],
#        ...,
#        [-1.62127289e+00, -5.80360856e-01, -5.85684132e-02],
#        [ 7.78262768e+00, -2.84567774e+00, -2.14082915e-01],
#        [ 4.53550406e+00, -1.29645378e+00,  2.04488529e-01]])

# %%
len(AA_3D.archetypes)
# Out:
# 3

# %%
def round2one(v):
    return v if v <= 1.0 else 1.0
color_map = np.array([[255, 0, 0], [0, 153, 51], [0, 0, 255], [255, 255, 0]]).T
sites_archetype = [np.array([round2one(x) for x in color_mapper(color_map, c)/255]) for c in AA_3D.alfa.T]
p = np.array(sites_archetype)
len(sites_archetype)
# Out:
# 7300

# %%
plot_3Dscatter_pca(pc, pca.explained_variance_ratio_, labels=sites_archetype, archetypes=AA_3D.archetypes)
# Out:
# 0.97% Total Exp. Var.

# %%
AA_3D.plot_simplex(AA_3D.alfa, plot_args={'c': sites_archetype})

# %%
n_comp = 3
res = np.dot(AA_3D.archetypes.T, pca.components_[:n_comp,:])+np.mean(sites, axis=0)

# %%
archetype_colors = [[1., 0., 0.], [0. , 0.6, 0.2], [0., 0., 1.], [1.0, 1.0, 0.]]
archetypes_bar_plot(res, CELL_TYPES, archetype_colors, y_axis='density', radius=RADIUS)

# %%
for a in range(4):
    archetype_simple_plot(res[a], a, archetype_colors, CELL_TYPES, y_axis='density', radius=RADIUS)

# %%
import pickle
with open("../../output/pca_3d_nature_gauss", "wb") as f:
    pickle.dump(pca, f)

with open("../../output/AA_3D_nature_gauss", "wb") as f:
    pickle.dump(AA_3D, f)

# %% [markdown]
# ## 5 archetype analysis

# %%
ROOT_DATA_PATH = "../../../data/tnbc_nature_cancer_dataset"
CELL_TYPES = ['Fibroblasts', 'Endothelial', 'T cells', 'B cells', 'Cancer', 'Vascular SMA+', 'Myoepithelial', 'Macrophages']
patient_ids = [ 88, 428, 357, 389, 303, 445, 374,  33, 549, 537, 477, 393, 429, 329, 443, 305, 105, 469, 555, 
               532,   6,  40, 415,   7, 221, 10, 395, 494, 332, 409,  87, 479, 359,  36, 265, 273, 229, 261, 
               184, 181, 521, 102, 468, 509,  92,  94, 331, 260, 250, 233, 234,236, 231, 170, 365, 175, 154,  19, 
               132,  98,  58,  61,  16,  63,432, 361, 263, 426, 366,  35, 340,   1, 336]

# %%
len(patient_ids)
# Out:
# 73

# %%
N_SITE = 100
RADIUS = 25

abs_log_ca_list = generate_abundance_matrix(CELL_TYPES, patient_ids, N_SITE, RADIUS, method='gaussian', snr=3, root=ROOT_DATA_PATH)
sites, patients_ids = join_abundance_matrices(abs_log_ca_list)
pca = PCA()
pc = pca.fit_transform(sites)

# %%
#SLOW
n_archs = list(range(2, 6))

lst_exp_var = []
for n_arch in n_archs:
    AA = ArchetypalAnalysis(n_archetypes = n_arch, 
                        tolerance = 0.001, 
                        max_iter = 200, 
                        random_state = 0, 
                        C = 0.0001, 
                        initialize = 'random',
                        redundancy_try = 30)
    AA.fit(pc[:, :3])
    lst_exp_var.append(AA.explained_variance_)

plt.plot(n_archs, lst_exp_var, '-o')
plt.ylim(0, 1)
plt.show()
# Out:
# Warning: A redundant archetype was recognised. The redundancy issue was resolved after 1 try(s) and a new candidate is replaced.

# %%
n_components = 3
n_archetypes = 5
AA_3D = ArchetypalAnalysis(n_archetypes = n_archetypes, 
                        tolerance = 0.001, 
                        max_iter = 200, 
                        random_state = 0,
                        C = 0.0001, 
                        initialize = 'random',
                        redundancy_try = 30)

# %%
AA_3D.fit_transform(pc[:, :n_components])
# Out:
# Warning: A redundant archetype was recognised. The redundancy issue was resolved after 1 try(s) and a new candidate is replaced.
# array([[-1.59850391, -0.55623713, -0.05481527],
#        [-1.59850391, -0.55623713, -0.05481527],
#        [-1.59850391, -0.55623713, -0.05481527],
#        ...,
#        [-1.59850391, -0.55623713, -0.05481527],
#        [ 2.64414809,  1.16280597,  0.97446502],
#        [-1.59850391, -0.55623713, -0.05481527]])

# %%
len(AA_3D.archetypes)
# Out:
# 3

# %%
def round2one(v):
    return v if v <= 1.0 else 1.0
color_map = np.array([[255, 0, 0], [0, 153, 51], [0, 0, 255], [255, 255, 0], [255, 0, 255]]).T
sites_archetype = [np.array([round2one(x) for x in color_mapper(color_map, c)/255]) for c in AA_3D.alfa.T]
p = np.array(sites_archetype)
len(sites_archetype)
# Out:
# 7300

# %%
plot_3Dscatter_pca(pc, pca.explained_variance_ratio_, labels=sites_archetype, archetypes=AA_3D.archetypes)
# Out:
# 0.97% Total Exp. Var.

# %%
AA_3D.plot_simplex(AA_3D.alfa, plot_args={'c': sites_archetype})

# %%
n_comp = 3
res = np.dot(AA_3D.archetypes.T, pca.components_[:n_comp,:])+np.mean(sites, axis=0)

# %%
archetype_colors = [[1., 0., 0.], [0. , 0.6, 0.2], [0., 0., 1.], [1.0, 1.0, 0.], [1.0, 0, 1]]
archetypes_bar_plot(res, CELL_TYPES, archetype_colors, y_axis='density', radius=RADIUS)
# Out:
# [ 0  3  6  9 12 15 18 21]
#
# [-3, -2, -1, 0, 1, 2]

# %%
for a in range(n_archetypes):
    archetype_simple_plot(res[a], a, archetype_colors, CELL_TYPES, y_axis='density', radius=RADIUS)

# %%
import pickle
with open("../../output/pca_3d_nature_gauss", "wb") as f:
    pickle.dump(pca, f)

with open("../../output/AA_3D_nature_gauss", "wb") as f:
    pickle.dump(AA_3D, f)
